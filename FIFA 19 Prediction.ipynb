# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('data.csv')
ls=df
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
count_category=df["Nationality"].value_counts()
count_category
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
# Brazil                   827
# Italy                    702
# Colombia                 618
# Japan                    478
# Netherlands              453
# Sweden                   397
# China PR                 392
# Chile                    391
# Republic of Ireland      368
# Mexico                   366
# United States            353
# Poland                   350
# Norway                   341
# Saudi Arabia             340
# Denmark                  336
# Korea Republic           335
# Portugal                 322
# Turkey                   303
# Austria                  298
# Scotland                 286
# Belgium                  260
# Australia                236
# Switzerland              220
# Uruguay                  149
# Senegal                  130
#                         ...
# Hong Kong                  2
# ...

# %%
count_category.hist()

# %%
df=pd.DataFrame(count_category)
df
# Out:
#                       Nationality
# England                      1662
# Germany                      1198
# Spain                        1072
# Argentina                     937
# France                        914
# Brazil                        827
# Italy                         702
# Colombia                      618
# Japan                         478
# Netherlands                   453
# Sweden                        397
# China PR                      392
# Chile                         391
# Republic of Ireland           368
# Mexico                        366
# United States                 353
# Poland                        350
# Norway                        341
# Saudi Arabia                  340
# Denmark                       336
# Korea Republic                335
# Portugal                      322
# Turkey                        303
# Austria                       298
# Scotland                      286
# Belgium                       260
# ...

# %%
DF1=df.reset_index()
DF1
# Out:
#                     index  Nationality
# 0                 England         1662
# 1                 Germany         1198
# 2                   Spain         1072
# 3               Argentina          937
# 4                  France          914
# 5                  Brazil          827
# 6                   Italy          702
# 7                Colombia          618
# 8                   Japan          478
# 9             Netherlands          453
# 10                 Sweden          397
# 11               China PR          392
# 12                  Chile          391
# 13    Republic of Ireland          368
# 14                 Mexico          366
# 15          United States          353
# 16                 Poland          350
# 17                 Norway          341
# 18           Saudi Arabia          340
# 19                Denmark          336
# 20         Korea Republic          335
# 21               Portugal          322
# 22                 Turkey          303
# ...

# %%
DF1.columns=["Nationality","Players"]
DF1
# Out:
#               Nationality  Players
# 0                 England     1662
# 1                 Germany     1198
# 2                   Spain     1072
# 3               Argentina      937
# 4                  France      914
# 5                  Brazil      827
# 6                   Italy      702
# 7                Colombia      618
# 8                   Japan      478
# 9             Netherlands      453
# 10                 Sweden      397
# 11               China PR      392
# 12                  Chile      391
# 13    Republic of Ireland      368
# 14                 Mexico      366
# 15          United States      353
# 16                 Poland      350
# 17                 Norway      341
# 18           Saudi Arabia      340
# 19                Denmark      336
# 20         Korea Republic      335
# 21               Portugal      322
# 22                 Turkey      303
# 23                Austria      298
# 24               Scotland      286
# 25                Belgium      260
# ...

# %%
Sample=DF1.head()
Sample
# Out:
#   Nationality  Players
# 0     England     1662
# 1     Germany     1198
# 2       Spain     1072
# 3   Argentina      937
# 4      France      914

# %%
Sample.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A357F165C0>]],
#       dtype=object)

# %%
plt.bar(Sample["Nationality"],Sample["Players"], color={"Red","Blue","Green","Yellow"})
plt.title("The Freq of Players of Top 5 Nationality")
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-579be0a1a5b9> in <module>
# ----> 1 plt.bar(Sample["Nationality"],Sample["Players"], color={"Red","Blue","Green","Yellow"})
#       2 plt.title("The Freq of Players of Top 5 Nationality")
#       3 plt.show
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(Sample["Nationality"],Sample["Players"], color={"Red","Blue","Green","Yellow"})
plt.title("The Freq of Players of Top 5 Nationality")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.pie(Sample["Players"],labels=Sample["Nationality"])
plt.title("The Pie Plot")
plt
# Out:
# <module 'matplotlib.pyplot' from 'E:\\Anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.pie(DF1["Players"],labels=DF1["Nationality"])
plt.title("The Pie Plot")
plt
# Out:
# <module 'matplotlib.pyplot' from 'E:\\Anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
ls
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
y=ls.Potential
y
# Out:
# 0        94
# 1        94
# 2        93
# 3        93
# 4        92
# 5        91
# 6        91
# 7        91
# 8        91
# 9        93
# 10       90
# 11       90
# 12       90
# 13       90
# 14       90
# 15       94
# 16       91
# 17       90
# 18       92
# 19       90
# 20       89
# 21       89
# 22       89
# 23       89
# 24       89
# 25       95
# 26       89
# 27       90
# 28       89
# 29       88
#          ..
# 18177    69
# 18178    65
# 18179    64
# 18180    58
# 18181    66
# 18182    65
# 18183    48
# 18184    55
# 18185    59
# 18186    64
# 18187    59
# 18188    62
# 18189    61
# 18190    67
# 18191    65
# 18192    64
# 18193    64
# 18194    65
# 18195    67
# 18196    61
# 18197    61
# 18198    70
# 18199    69
# 18200    62
# 18201    68
# 18202    65
# 18203    63
# 18204    67
# 18205    66
# 18206    66
# Name: Potential, Length: 18207, dtype: int64

# %%
x=ls[["Age","Overall"]]
x
# Out:
#        Age  Overall
# 0       31       94
# 1       33       94
# 2       26       92
# 3       27       91
# 4       27       91
# 5       27       91
# 6       32       91
# 7       31       91
# 8       32       91
# 9       25       90
# 10      29       90
# 11      28       90
# 12      32       90
# 13      32       90
# 14      27       89
# 15      24       89
# 16      24       89
# 17      27       89
# 18      26       89
# 19      26       89
# 20      29       89
# 21      31       89
# 22      32       89
# 23      30       89
# 24      33       89
# 25      19       88
# 26      26       88
# 27      26       88
# 28      26       88
# 29      27       88
# ...    ...      ...
# 18177   18       48
# 18178   18       48
# 18179   17       48
# 18180   22       48
# 18181   17       48
# 18182   18       48
# 18183   44       48
# 18184   18       48
# 18185   19       48
# 18186   20       47
# 18187   19       47
# 18188   17       47
# 18189   18       47
# ...

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2)

# %%
y_train
# Out:
# 5420     72
# 11355    66
# 12920    63
# 2460     74
# 16630    71
# 12514    67
# 12262    73
# 4183     75
# 5980     69
# 9732     66
# 14867    70
# 4965     72
# 1661     75
# 583      84
# 9593     68
# 12644    64
# 1035     79
# 16529    70
# 4215     73
# 12762    70
# 15891    65
# 14859    74
# 239      88
# 3497     76
# 4030     71
# 3449     77
# 14414    61
# 9034     66
# 16102    74
# 17499    63
#          ..
# 17347    74
# 6792     71
# 7115     68
# 12410    63
# 17554    58
# 14941    69
# 13278    79
# 11964    72
# 11723    76
# 306      82
# 13189    65
# 2561     74
# 13125    62
# 9715     66
# 2069     74
# 10113    81
# 10902    65
# 14879    60
# 7121     73
# 8074     72
# 6051     69
# 15401    70
# 3936     73
# 11923    69
# 2596     74
# 2029     82
# 6895     68
# 15821    64
# 2240     77
# 9350     74
# Name: Potential, Length: 14565, dtype: int64

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
from sklearn.linear_model import LinearRegression

# %%
regress=LinearRegression()

# %%
regress.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y1=regress.predict(x_test)

# %%
y1
# Out:
# array([74.71637955, 70.07290364, 70.64932044, ..., 68.47268385,
#        71.16122194, 71.3829207 ])

# %%
pred = np.array([20,87]).reshape(1,2)
pred
# Out:
# array([[20, 87]])

# %%
regress.predict(pred)
# Out:
# array([93.95936812])

# %%
plt.figure(figsize=(12,12))
plt.scatter(x['Age'],x['Overall'],c='r')
plt.xlabel("Age",fontsize=20)
plt.ylabel("Overall",fontsize=20)
plt.title("Age Vs Overall Relationship")
plt.grid(True)
plt.show()

# %%
ls.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...
